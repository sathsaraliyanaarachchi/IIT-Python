# %% [markdown]
# ### The Basic Four Calculator

# %%
num1=int(input("enter your first number"))
num2=int(input("enter your second number"))
add=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2
print("Addition:",add)
print("Subtraction:",sub)
print("Multiplication:",mul)
print("Division:",div)
# Out:
# enter your first number 200
# enter your second number 34
# Addition: 234
# Subtraction: 166
# Multiplication: 6800
# Division: 5.882352941176471
