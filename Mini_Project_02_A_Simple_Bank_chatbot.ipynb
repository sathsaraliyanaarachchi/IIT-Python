# %%
while True:
  user_input=input(f"Welcome to the ABS Bank CHATBOT? Type Exit to exit")
  user_input=user_input.lower()
  print(user_input)
  if user_input=="exit":
    print("Goodbye")
    break
  elif user_input in ["hi","hello","hey"]:
    print("Hello, I am your Banking CHATBOT, How can I help you?")
  elif "name" in user_input:
    print("My name is ABC Banking CHATBOT, I am here to you guide you with digital banking")
  elif "bank balance" in user_input:
    print("Hello,can you share your account number with me?")
  elif "contact information" in user_input:
    print("You can contact us via 94112333444, abcbank@bank.lk")
# Out:
# Welcome to the ABS Bank CHATBOT? Type Exit to exithi
# hi
# Hello, I am your Banking CHATBOT, How can I help you?
# Welcome to the ABS Bank CHATBOT? Type Exit to exitbank balance
# bank balance
# Hello,can you share your account number with me?
# Welcome to the ABS Bank CHATBOT? Type Exit to exit23451
# 23451
# Welcome to the ABS Bank CHATBOT? Type Exit to exitcontact information
# contact information
# You can contact us via 94112333444, abcbank@bank.lk
# Welcome to the ABS Bank CHATBOT? Type Exit to exitexit
# exit
# Goodbye
