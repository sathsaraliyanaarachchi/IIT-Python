# %%
print ("**********  CALCULATOR  **********")
print("menu")
print("Enter the correct value to proceed")
print ("1.Addition\n2.Subtraction\n3.Multiplication\n4.Division\n5.Exit")
while True:
    i=input("Enter the function number from the menu to proceed")
    if i=="5":
        print("Thank you!!!")
        break   
    if i=="1":
        print("*** Addition ***")
        num1=int(input("Enter the First Number"))
        num2=int(input("Enter the second Number"))
        Sum1=num1+num2
        print(Sum1)
    if i=="2":
        print("*** Subtraction ***")
        num1=int(input("Enter the First Number"))
        num2=int(input("Enter the second Number"))
        Sum2=num1-num2
        print(Sum2)
    if i=="3":
        print("*** Multiplication ***")
        num1=int(input("Enter the First Number"))
        num2=int(input("Enter the second Number"))
        Sum3=num1*num2
        print(Sum3)
    if i=="4":
        print("*** Divition ***")
        num1=int(input("Enter the First Number"))
        num2=int(input("Enter the second Number"))
        Sum2=num1/num2
        print(Sum2)
    print ("Invalid function number!!!!")
# Out:
# **********  CALCULATOR  **********
# menu
# Enter the correct value to proceed
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter the function number from the menu to proceed 1
# *** Addition ***
# Enter the First Number 2
# Enter the second Number 2
# 4
# Invalid function number!!!!
# Enter the function number from the menu to proceed 5
# Thank you!!!
